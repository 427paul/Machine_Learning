# %% [markdown]
# #판다스(Pandas)
# ##-파이썬의 데이터 분석 라이브러리
# ##-데이터 테이블을 다루는 도구
# ##-패널 데이터(2차원 데이터/행렬)을 다루는 라이브러리
# ##-기본적으로 넘파이를 사용함
# ##-넘파이 : 파이썬에서 배열을 다루는 최적의 라이브러리
# ##-넘파이를 효율적으로 사용하기 위해 다양한 함수 제공
# ##인덱싱, 연산, 전처리
# #데이터 프레임 : 데이터 테이블 전체를 포함하는 객체
# #시리즈 : 데이터프레임 중 하나의 열에 해당한느 데이터의 모음 객체
# #리스트, 튜플, 시리즈 -> 배열의 1차원 자료구조
# ##-데이터프레임의 한 행이나 열을 의미함

# %% [markdown]
# #시리즈 객체 :
# ##피쳐 벡터(Feature Vector)와 같은 개념
#
# ##1. 일반적으로 하나의 피쳐 데이터를 포함하는 형대
# ##2. 생성된 데이터프레임 안에 포함될 수 있음
# ##3. 다양한 데이터 타입이 시리즈 객체 형태로 반환되기도 함
#
# #시리즈 객체를 생성하면 3가지 요소(property) 생성
# ## 데이터 :
# ##- 기존 다른 객체처럼 값을 저장하는 요소
# ## 인덱스 :
# ##- 항상 0부터 시작하고, 숫자로만 할당하는 값
# ##- 시리즈 객체에서는 숫자, 문자열, 0 외의 값으로 시작하는 숫자, 순서가 일정하지 않은 숫자를 입력할 수도 있음
# ##- 시리즈 객체에서는 인덱스 값의 중복을 허용함
# ## 데이터 타입 :
# ##- 넘파이의 데이터 타입과 일치
# ##- 판다스는 넘파이의 래퍼(wrapper) 라이브러리
# ##- 넘파이의 모든 기능 지원하고 데이터 타입도 그래도 적용
#
# ##시리즈(Series) 객체는 넘파이 배열(ndarray)의 하위 클래스
# ##넘파이가 지원하는 어떠한 데이터 타임도 지원함
# ##인덱스와 반드시 정렬되어 있을 필요는 없음
# ##인덱스 값은 중복을 허용함

# %%
import pandas as pd
import numpy as np

# %%
list_data = [1,2,3,4,5]
list_name = ["a","b","c","d","e"]
obj = pd.Series(data = list_data, index = list_name)
obj
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
obj.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
obj.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(obj.values)
#ndarray는 numpy의 일부
# Out:
# numpy.ndarray

# %%
obj.dtype
# Out:
# dtype('int64')

# %%
obj.name = "number"
obj.index.name = "id"
obj
# Out:
# id
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: number, dtype: int64

# %%
dict_data = {'a':1,'b':2,'c':3,'d':4,'e':5}
obj = pd.Series(dict_data, dtype = np.float32, name = "example_data")
obj
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# Name: example_data, dtype: float32

# %%
dict_data2 = dict_data.copy()
indexes = ['a','b','c','d','e','f','g','h']
obj2 = pd.Series(dict_data2, index = indexes)
obj2
#NaN : Not a Number
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# f    NaN
# g    NaN
# h    NaN
# dtype: float64

# %% [markdown]
# #데이터 프레임 객체
# ##-데이터 테이블 전체를 지칭하는 객체
# ##-넘파이 배열의 특성을 그대로 가짐
# ##-인덱싱 : 열과 행 각각 사용하여 하나의 데이터에 접근

# %%
from google.colab import drive
drive.mount('/content/drive')
#구글 드라이브에 있는 자료 불러오는 기능
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/friend_list.csv', sep = '\s+',header = None)
#구글 드라이브의 파일 주소 입력
#\s+ : 데이터 구분 기준 : 공백(tab)
#데이터가 메모장인 경우(예) sep을 사용하여 데이터를 구분한다
#header : 첫 줄이 데이터에 대한 설명인 경우
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-9aa4d66b5939> in <cell line: 0>()
# ----> 1 df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/friend_list.csv', sep = '\s+',header = None)
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
#컴퓨터에서 파일 불러오기
# Out:
#      <input type="file" id="files-b929598f-6c2c-402c-b59d-412196c3d142" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b929598f-6c2c-402c-b59d-412196c3d142">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file = open('health_screenings_2020.csv')
df = pd.read_csv(file, encoding='cp949')

# %%
df
# Out:
#      year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 0    2020         36       1         9     165      60   72.1       1.2
# 1    2020         27       2        13     150      65   81.0       0.8
# 2    2020         11       2        12     155      55   70.0       0.6
# 3    2020         31       1        13     160      70   90.8       1.0
# 4    2020         41       2        12     155      50   75.2       1.5
# ..    ...        ...     ...       ...     ...     ...    ...       ...
# 995  2020         48       1        12     165      70   92.0       0.5
# 996  2020         41       1        12     165      70   88.0       1.2
# 997  2020         48       2        14     155      55   80.2       0.5
# 998  2020         41       2        14     150      55   79.5       1.0
# 999  2020         28       1        11     160      60   86.0       1.2
#
#      eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# ...

# %%
raw_data = {"first_name":['Jason','Molly','Tina','Jake','Amy'],
            "last_name":['Miller','Jackson','Ali','Milner','Cooze'],
            "age":[42,52,36,24,74],
            "city":['San Francisco','Baltimore','Miami','Douglas','Boston']}
df = pd.DataFrame(raw_data)

# %%
df
# Out:
#   first_name last_name  age           city
# 0      Jason    Miller   42  San Francisco
# 1      Molly   Jackson   52      Baltimore
# 2       Tina       Ali   36          Miami
# 3       Jake    Milner   24        Douglas
# 4        Amy     Cooze   74         Boston

# %%
df = pd.DataFrame(raw_data, columns = ['age','city'])
df
# Out:
#    age           city
# 0   42  San Francisco
# 1   52      Baltimore
# 2   36          Miami
# 3   24        Douglas
# 4   74         Boston

# %%
df = pd.DataFrame(raw_data, columns = ['first_name','last_name','age','city','debt'])
df
# Out:
#   first_name last_name  age           city debt
# 0      Jason    Miller   42  San Francisco  NaN
# 1      Molly   Jackson   52      Baltimore  NaN
# 2       Tina       Ali   36          Miami  NaN
# 3       Jake    Milner   24        Douglas  NaN
# 4        Amy     Cooze   74         Boston  NaN
